# %% [markdown]
# ![firstLR.PNG](attachment:firstLR.PNG)

# %% [markdown]
# **Furthur feature engineering will be required to have a better model.**
# **Location(Zip,City,Division)**
# The features EAST, NORTH, SOUTH are 4% of the total data set and the rest 95% is CENTRAL.
# Will take these dummy variables out and go in depth by cities with the highest average price.
# La Jolla, Carmel_Valley, Point_Loma are in top 5 of average price and they each have more than 150 data points.
